# %% [markdown]
# ## Обзор
#
# Вы планируете посмотреть какой-то фильм. Можете ли Вы доверять онлайн-рейтингам и отзывам о фильмах? *Особенно* если та компания, которая занимается рейтингами и отзывами, *также* зарабатывает на продаже билетов на фильмы. Есть ли у таких компаний тенденция выдавать завышенные или заниженные рейтинги?
#
# ### Цель проекта:
#
# **Цель проекта - выполнить шаги по мотивам статьи на сайте fivethirtyeight.com о рейтингах и посмотреть, сможем ли мы прийти к тем же выводам, которые приведены в статье. Вы будете применять Ваши навыки работы с pandas и навыки визуализации данных для того, чтобы определить, предоставляла ли компания Fandango завышенные рейтинги в 2015 году для того, чтобы продавать больше билетов.**
#
# ---
# ---
#
# **Выполните шаги, написанные жирным шрифтом.**
#
# ---
# ----
#
# ## Часть 1: Исследуем данные
#
#
# **ЗАДАНИЕ (ОПЦИОНАЛЬНО): Это задание не является обязательным, но если Вы хорошо знаете английский язык, то прочтите эту статью, по мотивам которой строится наш проект: [Be Suspicious Of Online Movie Ratings, Especially Fandango’s](http://fivethirtyeight.com/features/fandango-movies-ratings/)**

# %% [markdown]
# ----
#
# **ЗАДАНИЕ: Прочитайте описание двух .csv-файлов, которые мы будем далее загружать и обрабатывать:**
#
# ### Данные
#
# Исходные данные для статьи [Be Suspicious Of Online Movie Ratings, Especially Fandango’s](http://fivethirtyeight.com/features/fandango-movies-ratings/) находятся в свободном доступе по следующей ссылке на github: https://github.com/fivethirtyeight/data. Это два csv-файла. В одном файле данные о рейтингах от компании Fandango, а в другом файле агрегированные данные о рейтингах от других компаний, таких как Metacritic, IMDB и Rotten Tomatoes.
#
# #### all_sites_scores.csv

# %%
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# 2                     90          64              8.1   7.8
# 3                     84          22              4.7   5.4
# 4                     28          29              3.4   5.1
# ..                   ...         ...              ...   ...
# 141                   78          67              7.9   7.4
# 142                   82          83              7.5   7.2
# 143                   78          89              8.8   7.4
# 144                   81          90              7.3   7.8
# 145                   63          68              6.4   6.7
#
#      Metacritic_user_vote_count  IMDB_user_vote_count
# 0                          1330                271107
# 1                           249                 65709
# 2                           627                103660
# 3                            31                  3136
# 4                            88                 19560
# ..                          ...                   ...
# 141                          33                  7367
# 142                          60                 24116
# 143                         123                 24345
# 144                          19                  1955
# 145                          19                  5289
#
# [146 rows x 8 columns]

# %% [markdown]
# -----
#
# Файл `all_sites_scores.csv` содержит все фильмы, для которых есть рейтинг Rotten Tomatoes, рейтинг RT User, оценка Metacritic, оценка Metacritic User и оценка IMDb, а также как минимум 30 отзывов от фанатов на Fandango. Данные Fandango были выгружены 24 августа 2015.

# %% [markdown]
# Колонка | Определение
# --- | -----------
# FILM | Название фильма
# RottenTomatoes | Оценка "Rotten Tomatoes Tomatometer" для этого фильма
# RottenTomatoes_User | Оценка "Rotten Tomatoes user" для этого фильма
# Metacritic | Оценка "Metacritic" для этого фильма
# Metacritic_User | Оценка "Metacritic user" для этого фильма
# IMDB | Оценка "IMDb user" для этого фильма
# Metacritic_user_vote_count | Количество голосов за этот фильм от пользователей Metacritic
# IMDB_user_vote_count | Количество голосов за этот фильм от пользователей IMDb

# %% [markdown]
# ----
# ----
#
# #### fandango_scape.csv

# %% [markdown]
# Фильм `fandango_scrape.csv` содержит данные о фильмах, которые авторы статьи выгрузили с Fandango.
#
# Колонка | Определение
# --- | ---------
# FILM | Название фильма
# STARS | Количество звёзд на Fandango.com
# RATING |  Рейтинг Fandango - значение, прочитанное с HTML-страницы. Это средний рейтинг фильма.
# VOTES | Количество голосов пользователей, которые написали отзыв о фильме (на момент выгрузки данных).

# %% [markdown]
# ----
#
# **ЗАДАНИЕ: Импортируйте библиотеки, которые по Вашему мнению могут Вам понадобиться:**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# 4                 19560

# %% [markdown]
# ## Часть 2: Сравниваем рейтинги Fandango и другие пользовательские рейтинги
#
# Сначала давайте изучим рейтинги Fandango и посмотрим, совпадут ли результаты нашего анализа с выводами в статье.
#
# **ЗАДАНИЕ: Выполните ячейку ниже для загрузки файла fandango_scrape.csv**

# %%
fandango = pd.read_csv("fandango_scrape.csv")

# %% [markdown]
# **ЗАДАНИЕ: Изучите свойства полученного объекта DataFrame - выведите несколько первых строк, а также общую информацию.**

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %% [markdown]
# **ЗАДАНИЕ: Давайте изучим связь между популярностью фильма и его рейтингом. Нарисуйте график scatterplot, показывающий связь между колонками RATING и VOTES. Можете поменять стилизацию графика по Вашему вкусу.**

# %%
plt.figure(figsize=(12,5), dpi=200)
sns.scatterplot(x='RATING', y='VOTES', data=fandango)
# Out:
# <AxesSubplot:xlabel='RATING', ylabel='VOTES'>

# %% [markdown]
# **ЗАДАНИЕ: Вычислите корреляцию между колонками:**

# %%
fandango.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %%
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %% [markdown]
# **ЗАДАНИЕ: Сделаем предположение, что каждая строка в колонке FILM содержит значение в следующем формате:**
#
#     Название Фильма (Год)
#
# **Создайте новую колонку, в ней возьмите из строки FILM только год, и назовите эту новую колонку YEAR**

# %%
fandango['YEAR']=fandango['FILM'].str.replace(")","").str.split('(')[:].str[1]
fandango['YEAR']=fandango['YEAR'].str.replace("Stratford Festival","2015").str.replace("Shi Gu","2015")
fandango['YEAR']= fandango['YEAR']
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1        Jurassic World (2015)    4.5     4.5  34390  2015
# 2       American Sniper (2015)    5.0     4.8  34085  2015
# 3             Furious 7 (2015)    5.0     4.8  33538  2015
# 4            Inside Out (2015)    4.5     4.5  15749  2015

# %% [markdown]
# **ЗАДАНИЕ: Сколько фильмов содержится в наборе данных Fandango, в разбивке по годам?**

# %%
fandango['YEAR'].value_counts()
# Out:
# 2015     474
# 2014      23
# 2015       3
# 1964       1
# 2012       1
# 2014       1
# 2016       1
# Name: YEAR, dtype: int64

# %% [markdown]
# **ЗАДАНИЕ: Визуализируйте количество фильмов в год с помощью графика:**

# %%
plt.figure(figsize=(2,2),dpi=200)
plt.rcParams.update({'font.size': 5})
plt.ylim(0,500)
sns.countplot(data=fandango, x='YEAR')
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='count'>

# %% [markdown]
# **ЗАДАНИЕ: Какие 10 фильмов получили наибольшее количество голосов (votes)?**

# %%
fandango.nlargest(10, 'VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %% [markdown]
# **ЗАДАНИЕ: Сколько фильмов имеет нулевое количество голосов (votes)?**

# %%
len(fandango[fandango[ 'VOTES'] == 0])
# Out:
# 69

# %%
# Out:
# 69

# %% [markdown]
# **ЗАДАНИЕ: Создайте DataFrame только с теми фильмами, которые имеют голоса (votes) - то есть, удалите те фильмы, у которых нет ни одного голоса.**

# %%
fandango = fandango[fandango.VOTES > 0]

# %% [markdown]
# ----
#
# **Из-за особенностей отображения рейтингов в виде звёзд на страницах HTML, истинные рейтинги пользователей могут немного отличаться от рейтингов, которые показываются пользователю. Давайте визуализируем эту разницу распределений.**
#
# **ЗАДАНИЕ: Создайте график KDE plot (или несколько таких графиков), который отображает распределение отображаемых рейтингов (STARS) и истинных рейтингов на основе голосов пользователей (RATING). Обрежьте диапазон KDE в пределах 0-5.**

# %%
plt.figure(figsize=(6,3),dpi=200)
sns.kdeplot(data=fandango, x='RATING',shade=True, label='True Rating')
sns.kdeplot(data=fandango, x='STARS',shade=True, label='Stars Displayed')
plt.rcParams.update({'font.size': 6})
plt.xlim(0,5)
plt.legend(loc=(1.05, 0.5))

# %% [markdown]
# **ЗАДАНИЕ: Теперь давайте посчитаем эту разницу в численном виде; Создайте новую колонку, в которой сохраните разницу между колонками STARS и RATING с помощью обычного вычитания STARS-RATING, а также выполните округление до одной десятичной цифры после запятой.**

# %%
fandango['STARS_DIFF']=(fandango['STARS']-fandango['RATING']).round(1)
# Out:
# D:\DataSience\Anaconda\envs\Vasyl_ML\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fandango
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015         0.0
# 431            The Intern (2015)    5.0     5.0      1  2015         0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015         0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015         0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015         0.0
#
# [435 rows x 6 columns]

# %% [markdown]
# **ЗАДАНИЕ: Нарисуйте график count plot для отображения того, сколько раз встречается то или иное значение разницы между STAR и RATING:**

# %%
plt.figure(figsize=(10,2),dpi=200)
plt.rcParams.update({'font.size': 5})
sns.countplot(data=fandango, x='STARS_DIFF', palette='rocket')
# Out:
# <AxesSubplot:xlabel='STARS_DIFF', ylabel='count'>

# %% [markdown]
# **ЗАДАНИЕ: На этом графике мы видим, что один из фильмов имеет разницу в 1 звезду между отображаемым рейтингом и истинным рейтингом! Найдите этот фильм.**

# %%
fandango[fandango.STARS_DIFF == 1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %% [markdown]
# ## Часть 3: Сравнение рейтингов Fandango с рейтингами других компаний
#
# Давайте посмотрим, как рейтинги Fandango соотносятся с рейтингами других компаний.
#
# **ЗАДАНИЕ: Выполните ячейку ниже, чтобы загрузить файл "all_sites_scores.csv"**

# %%
all_sites = pd.read_csv("all_sites_scores.csv")

# %% [markdown]
# **ЗАДАНИЕ: Изучите общие свойства полученного объекта DataFrame.**

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# 4                 19560

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# min      4.000000                    4.000000            243.000000
# 25%      6.300000                   33.250000           5627.000000
# 50%      6.900000                   72.500000          19103.000000
# 75%      7.400000                  168.500000          45185.750000
# max      8.600000                 2375.000000         334164.000000

# %% [markdown]
# ### Рейтинги от Rotten Tomatoes
#
# Начнём с рейтингов Rotten Tomatoes. Здесь два набора рейтингов - рейтинги, опубликованные официальными критиками, и пользовательские рейтинги.
#
# **ЗАДАНИЕ: Нарисуйте график scatterplot, изображающий для Rotten Tomatoes связь между рейтингами от критиков и пользовательскими рейтингами.**

# %%
plt.figure(figsize=(10,4),dpi=200)
plt.rcParams.update({'font.size': 8})
plt.ylim(0,100)
plt.xlim(0,100)
sns.scatterplot(x='RottenTomatoes', y='RottenTomatoes_User', data=all_sites)
# Out:
# <AxesSubplot:xlabel='RottenTomatoes', ylabel='RottenTomatoes_User'>

# %% [markdown]
# Давайте изучим численную разницу между этими двумя рейтингами. Мы посчитаем эту разницу с помощью формулы RottenTomatoes-RottenTomatoes_User. Полученные значения Rotten_Diff - это рейтинг критиков минус рейтинг пользователей. Близкие к нулю значения говорят о том, что критики и пользователи согласны друг с другом. Большие положительные значения - когда критики оценили фильм намного выше, чем пользователи. А большие отрицательные значения - наоборот, пользователи оценили фильм намного выше, чем критики.
#
# **ЗАДАНИЕ: Создайте новую колонку, в которой сохраните разницу между рейтингом от критиков и пользовательским рейтингом для Rotten Tomatoes. Используйте формулу RottenTomatoes-RottenTomatoes_User.**

# %%
all_sites['Rotten_Diff']=(all_sites['RottenTomatoes']-all_sites['RottenTomatoes_User']).round(1)
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12
# 1                 65709            5
# 2                103660          -10
# 3                  3136          -66
# 4                 19560          -14

# %% [markdown]
# Теперь давайте посчитаем среднее значение полученной разницы по всему набору данных. Поскольку разница может быть как положительной, так и отрицательной, то давайте сначала возьмём абсолютные величины всех значений, и только после этого посчитаем среднее значение. Таким образом мы получим среднее значение абсолютной разницы между рейтингами от критиков и пользовательскими рейтингами.

# %% [markdown]
# **ЗАДАНИЕ: Вычислите среднюю абсолютную разницу между рейтингами от критиков и пользовательскими рейтингами для Rotten Tomatoes, согласно описанию выше.**

# %%
abs(all_sites['Rotten_Diff']).mean()
# Out:
# 15.095890410958905

# %% [markdown]
# **ЗАДАНИЕ: Нарисуйте график распределения разницы между рейтингами от критиков и пользовательскими рейтингами для Rotten Tomatoes. На этом графике будут отрицательные значения. Для отображения этого распределения можете использовать как KDE, так и гистограммы.**

# %%
plt.figure(figsize=(5,8), dpi=200)
sns.displot(data=all_sites,x='Rotten_Diff',kde=True, height=10, aspect=2)
plt.rcParams.update({'font.size': 20})
plt.title('RottenTomatoes minus RottenTomatoes_User')
# Out:
# Text(0.5, 1.0, 'RottenTomatoes minus RottenTomatoes_User')

# %% [markdown]
# **ЗАДАНИЕ: Далее нарисуйте график распределения *абсолютных значений* разницы между рейтингами от критиков и пользовательскими рейтингами для Rotten Tomatoes.**

# %%
plt.figure(figsize=(5,8), dpi=200)
sns.displot(data=all_sites,x=abs(all_sites['Rotten_Diff']),kde=True, height=10, aspect=2)
plt.rcParams.update({'font.size': 45})
plt.title('Abs RottenTomatoes minus RottenTomatoes_User')
# Out:
# Text(0.5, 1.0, 'Abs RottenTomatoes minus RottenTomatoes_User')

# %% [markdown]
# **Давайте выясним, какие фильмы наиболее отличаются по рейтингам. Сначала выведите 5 фильмов с наибольшей по модулю *отрицательной* разницей рейтингов. Поскольку мы вычисляли разницу рейтингов по формуле Critics Rating - Users Rating, большие по модулю отрицательные значения говорят о том, что пользователи в среднем оценили эти фильмы намного выше, чем критики.**

# %% [markdown]
# **ЗАДАНИЕ: Какие 5 фильмов в среднем были выше всего оценены пользователями, по сравнению с оценками от критиков:**

# %%
all_sites.nsmallest(5, 'Rotten_Diff')[['FILM', 'Rotten_Diff']]
# Out:
#                           FILM  Rotten_Diff
# 3       Do You Believe? (2015)          -66
# 85           Little Boy (2015)          -61
# 105    Hitman: Agent 47 (2015)          -42
# 134    The Longest Ride (2015)          -42
# 125  The Wedding Ringer (2015)          -39

# %% [markdown]
# **ЗАДАНИЕ: Далее наоборот - отобразите 5 фильмов, которые в среднем были выше всего оценены критиками, по сравнению с оценками от пользователей.**

# %%
all_sites.nlargest(5, 'Rotten_Diff')[['FILM', 'Rotten_Diff']]
# Out:
#                                  FILM  Rotten_Diff
# 69                  Mr. Turner (2014)           42
# 112                 It Follows (2015)           31
# 115          While We're Young (2015)           31
# 37               Welcome to Me (2015)           24
# 40   I'll See You In My Dreams (2015)           24

# %% [markdown]
# ## Рейтинги от MetaCritic
#
# Далее давайте быстро взглянем на рейтинги от MetaCritic. Они тоже отображают два типа рейтингов - как свои официальные рейтинги, так и пользовательские рейтинги.

# %% [markdown]
# **ЗАДАНИЕ: Нарисуйте график scatterplot для сравнения рейтингов Metacritic и Metacritic User.**

# %%
plt.figure(figsize=(10,4),dpi=200)
plt.rcParams.update({'font.size': 8})
plt.ylim(0,10)
plt.xlim(0,100)
sns.scatterplot(x='Metacritic', y='Metacritic_User', data=all_sites)
# Out:
# <AxesSubplot:xlabel='Metacritic', ylabel='Metacritic_User'>

# %% [markdown]
# ## Рейтинги от IMDB
#
# И наконец, посмотрим на рейтинги от IMDB. Обратите внимание, что Metacritic и IMDB показывают количество голосов. Посмотрим на наиболее популярные фильмы.
#
# **ЗАДАНИЕ: Нарисуйте график scatterplot для изображения связи между количеством голосов на MetaCritic и количеством голосов на IMDB.**

# %%
plt.figure(figsize=(10,4),dpi=200)
plt.rcParams.update({'font.size': 8})
sns.scatterplot(x='Metacritic_user_vote_count', y='IMDB_user_vote_count', data=all_sites)
# Out:
# <AxesSubplot:xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %% [markdown]
# **Здесь мы видим два "выброса" - точки, очень сильно отличающиеся от всех других точек. Один фильм получил наибольшее количество голосов на IMDB, но только 500 голосов на Metacritic. Что это за фильм?**
#
# **ЗАДАНИЕ: Какой фильм получил наибольшее количество голосов на IMDB?**

# %%
all_sites.nlargest(1, 'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Rotten_Diff
# 14                334164           -2

# %% [markdown]
# **ЗАДАНИЕ: Какой фильм получил наибольшее количество голосов на Metacritic?**

# %%
all_sites.nlargest(1, 'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Rotten_Diff
# 88                292023            9

# %% [markdown]
# ## Сравнение рейтингов Fandango с рейтингами других компаний
#
# Давайте наконец выясним, являлись ли рейтинги Fandango искусственно завышенными, чтобы продавать больше билетов.

# %% [markdown]
# **ЗАДАНИЕ: Объедините таблицу fandango с таблицей all_sites. Не каждый фильм в таблице Fandango найдётся в таблице all_sites, потому что некоторые фильмы Fandango имеют очень мало отзывов или вообще не имеют отзывов. Но мы хотим сравнивать только те фильмы, которые есть в обеих таблицах. Поэтому сделайте объединение "*inner* merge" двух наборов данных, сопоставляя строки по колонке FILM.**

# %%
all_sites=pd.merge(fandango,all_sites,how='inner',on='FILM')
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   YEAR                        145 non-null    object
#  5   STARS_DIFF                  145 non-null    float64
#  6   RottenTomatoes              145 non-null    int64
#  7   RottenTomatoes_User         145 non-null    int64
#  8   Metacritic                  145 non-null    int64
#  9   Metacritic_User             145 non-null    float64
#  10  IMDB                        145 non-null    float64
#  11  Metacritic_user_vote_count  145 non-null    int64
#  12  IMDB_user_vote_count        145 non-null    int64
#  13  Rotten_Diff                 145 non-null    int64
# dtypes: float64(5), int64(7), object(2)
# memory usage: 17.0+ KB

# %%
all_sites.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015         0.0
#
#    RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0              25                   42          46              3.2   4.2
# 1              71                   81          59              7.0   7.3
# 2              72                   85          72              6.6   7.4
# 3              81                   84          67              6.8   7.4
# 4              98                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff
# 0                         778                179506          -17
# 1                        1281                241807          -10
# 2                         850                251856          -13
# 3                         764                207211           -3
# 4                         807                 96252            8

# %% [markdown]
# ### Нормализация колонок до диапазона 0-5 в соответствии с колонками STARS и RATINGS от Fandango
#
# Обратите внимание, что компании Rotten Tomatoes, Metacritic и IMDB используют другую шкалу измерения рейтингов, чем шкала от 0 до 5 звезд в Fandango. Чтобы выполнить сравнения, нам нужно *нормализовать* эти значения, чтобы они попадали с диапазон от 0 до 5 звёзд.
#
# **ЗАДАНИЕ: Добавьте дополнительные колонки в all_sites, и запишите в них нормализованные значения рейтингов от 0 до 5. Это можно сделать разными способами.**
#
# В качестве подсказки, можете прочитать вот эту статью: https://stackoverflow.com/questions/26414913/normalize-columns-of-pandas-data-frame
#
#
# Ещё одна подсказка - простой способ конвертации рейтингов:
# * 100/20 = 5
# * 10/2 = 5

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015         0.0

# %%
def normalizator(df, fandango_diff_max_min, feature_names):
    result = df.copy()
    for feature_name in feature_names.keys():
        diff_max_min_value = df[feature_name].max()-df[feature_name].min()
        result[feature_names[feature_name]] = (df[feature_name]* fandango_diff_max_min/ diff_max_min_value).round(1)
    return result

# %%
feature_names={'RottenTomatoes_User':'RTU_Norm', 'Metacritic_User':'Meta_U_Norm', 'IMDB':'IMDB_Norm'}
fandango_diff_max_min=fandango['STARS'].max()-fandango['STARS'].min()
all_sites=normalizator(all_sites, fandango_diff_max_min, feature_names)

# %%
feature_names={'RottenTomatoes':'RT_Norm', 'Metacritic':'Meta_Norm'}
fandango_diff_max_min=fandango['RATING'].max()-fandango['RATING'].min()
all_sites=normalizator(all_sites, fandango_diff_max_min, feature_names)

# %%
all_sites.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015         0.0
#
#    RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0              25                   42          46              3.2   4.2
# 1              71                   81          59              7.0   7.3
# 2              72                   85          72              6.6   7.4
# 3              81                   84          67              6.8   7.4
# 4              98                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff  RTU_Norm  \
# 0                         778                179506          -17       2.3
# 1                        1281                241807          -10       4.4
# 2                         850                251856          -13       4.6
# 3                         764                207211           -3       4.5
# 4                         807                 96252            8       4.9
#
#    Meta_U_Norm  IMDB_Norm  RT_Norm  Meta_Norm
# 0          1.8        3.7      1.1        2.3
# 1          3.9        6.3      3.0        2.9
# 2          3.7        6.4      3.0        3.6
# 3          3.8        6.4      3.4        3.3
# 4          4.9        7.5      4.1        4.6

# %% [markdown]
# **ЗАДАНИЕ: Далее создайте DataFrame с названием norm_scores, в котором оставьте только нормализованные рейтинги. Также оставьте колонки STARS и RATING из исходной таблицы fandango.**

# %%
norm_scores=all_sites[['STARS','RATING','RT_Norm','RTU_Norm','Meta_Norm','Meta_U_Norm','IMDB_Norm']]

# %%
norm_scores.head()
# Out:
#    STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm
# 0    4.0     3.9      1.1       2.3        2.3          1.8        3.7
# 1    4.5     4.5      3.0       4.4        2.9          3.9        6.3
# 2    5.0     4.8      3.0       4.6        3.6          3.7        6.4
# 3    5.0     4.8      3.4       4.5        3.3          3.8        6.4
# 4    4.5     4.5      4.1       4.9        4.6          4.9        7.5

# %% [markdown]
# ### Сравнение распределений рейтингов от разных компаний
#
#
# А теперь момент истины! Действильно ли Fandango показывал неоправданно высокие рейтинги? Мы уже знаем, что отображаемые значения RATING были выше значений STARS. Но являются ли сами рейтинги в среднем более высокими, чем у других компаний?
#
#
# **ЗАДАНИЕ: Нарисуйте график, сравнивающий распределения нормализованных рейтингов от всех компаний. Это можно сделать разными способами, но попробуйте использовать Seaborn KDEplot (посмотрите документацию). Не беспокойтесь, если Ваш график будет выглядеть немного иначе нашего примера. Главное, чтобы были видны отличия между отдельными распределениями.**
#
# p.s. если Вам нужно переместить легенду на графике seaborn kdeplot, то это можно сделать вот так: https://github.com/mwaskom/seaborn/issues/2280

# %%
plt.figure(figsize=(8,3),dpi=200)

plt.legend(loc='upper left')
kdes=sns.kdeplot(data=norm_scores,shade=True)
kdes.legend_._set_loc(2)
plt.rcParams.update({'font.size': 6})
plt.xlim(0,5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **Мы сразу видим, что рейтинги Fandango очень сдвинуты справо. Интересно также, что рейтинги RT от критиков имеют очень пологое распределение. Давайте сравним только эти два распределения.**
#
# **ЗАДАНИЕ: Нарисуйте график KDE plot, сравнивающий распределение рейтингов Rotten Tomatoes от критиков и распределение рейтингов STARS от Fandango.**

# %%
plt.figure(figsize=(8,3),dpi=200)

plt.legend(loc='upper left')
kdes=sns.kdeplot(data=norm_scores[['RT_Norm','STARS']],shade=True)
kdes.legend_._set_loc(2)
plt.rcParams.update({'font.size': 6})
plt.xlim(0,5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **ОПЦИОНАЛЬНОЕ ЗАДАНИЕ: Нарисуйте график histplot, сравнивающий все нормализованные рейтинги.**

# %%
plt.figure(figsize=(8,2), dpi=200)
sns.histplot(data=norm_scores)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ### Как различные компании оценивают фильмы с наименьшими рейтингами?
#
# **ЗАДАНИЕ: Нарисуйте график clustermap для всех нормализованных рейтингов. Обратите внимание на отличия в рейтингах между разными компаниями. Фильмы с высокими рейтингами должны попадать в одни кластеры, а фильмы с низкими рейтингами в другие кластеры. Замечание: для этого графика clustermap вовсе необязательно указывать колонку FILM в качестве индекса, так что при желании можете удалить эту колонку перед построением графика clustermap.**

# %%
sns.clustermap(data=norm_scores)

# %%
norm_scores
# Out:
#      STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm
# 0      4.0     3.9      1.1       2.3        2.3          1.8        3.7
# 1      4.5     4.5      3.0       4.4        2.9          3.9        6.3
# 2      5.0     4.8      3.0       4.6        3.6          3.7        6.4
# 3      5.0     4.8      3.4       4.5        3.3          3.8        6.4
# 4      4.5     4.5      4.1       4.9        4.6          4.9        7.5
# ..     ...     ...      ...       ...        ...          ...        ...
# 140    3.5     3.5      3.7       3.4        3.4          3.6        5.8
# 141    4.0     3.6      4.0       4.4        4.3          3.5        6.1
# 142    4.5     4.2      3.9       4.5        3.3          3.9        6.8
# 143    4.0     3.9      4.0       4.6        4.2          4.1        6.4
# 144    3.5     3.1      2.5       2.5        3.3          3.2        5.5
#
# [145 rows x 7 columns]

# %% [markdown]
# **ЗАДАНИЕ: Мы видели, что рейтинги Fandango явно выше рейтингов других компаний, особенно если смотреть на округлённые вверх значения рейтингов. Давайте посмотрим на 10 фильмов с наихудшими рейтингами по версии Rotten Tomatoes Critic - какие это 10 фильмов? Какие нормализованные рейтинги дали этим фильмам другие компании? Возможно Вам понадобится колонка FILM, так что если вы удаляли её, то верните эту колонку обратно.**

# %%
norm_scores['FILM']=all_sites['FILM']
# Out:
# D:\DataSience\Anaconda\envs\Vasyl_ML\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
norm_scores.nsmallest(10, 'RT_Norm')
# Out:
#     STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm  \
# 49    3.5     3.5      0.2       1.9        0.6          1.3        3.7
# 54    4.0     3.7      0.3       2.0        1.5          2.1        4.3
# 84    4.0     3.9      0.3       2.6        1.4          1.8        5.1
# 25    4.5     4.1      0.4       2.5        1.3          2.6        5.3
# 28    3.0     2.7      0.4       1.1        1.3          1.4        3.5
# 50    4.0     3.6      0.4       1.9        1.5          3.1        4.0
# 77    3.5     3.2      0.5       1.9        1.5          2.2        4.8
# 78    3.5     3.2      0.5       1.6        1.3          1.8        4.8
# 83    3.5     3.3      0.5       1.8        1.5          2.8        4.8
# 87    3.5     3.2      0.5       1.5        1.6          2.1        4.7
#
#                              FILM
# 49  Paul Blart: Mall Cop 2 (2015)
# 54             Hot Pursuit (2015)
# 84        Hitman: Agent 47 (2015)
# 25                 Taken 3 (2015)
# 28          Fantastic Four (2015)
# 50       The Boy Next Door (2015)
# 77             Seventh Son (2015)
# 78               Mortdecai (2015)
# 83              Sinister 2 (2015)
# 87     Unfinished Business (2015)

# %%
norm_scores=norm_scores.drop('FILM', axis= 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23760\1677230607.py in <module>
# ----> 1 norm_scores=norm_scores.drop('FILM', axis= 1)
#
# D:\DataSience\Anaconda\envs\Vasyl_ML\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4167             level=level,
#    4168             inplace=inplace,
# -> 4169             errors=errors,
#    4170         )
#    4171
#
# D:\DataSience\Anaconda\envs\Vasyl_ML\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# -> 3884                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3885
#    3886         if inplace:
#
# D:\DataSience\Anaconda\envs\Vasyl_ML\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3916                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3917             else:
# -> 3918                 new_axis = axis.drop(labels, errors=errors)
#    3919             result = self.reindex(**{axis_name: new_axis})
#    3920
#
# D:\DataSience\Anaconda\envs\Vasyl_ML\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5276         if mask.any():
#    5277             if errors != "ignore":
# -> 5278                 raise KeyError(f"{labels[mask]} not found in axis")
#    5279             indexer = indexer[~mask]
#    5280         return self.delete(indexer)
#
# KeyError: "['FILM'] not found in axis"

# %% [markdown]
# **ФИНАЛЬНОЕ ЗАДАНИЕ: визуализируйте распределение рейтингов от всех компаний для 10 фильмов с наихудшими рейтингами.**

# %%
plt.figure(figsize=(8,3),dpi=200)
plt.legend(loc='upper left')
kdes=sns.kdeplot(data=norm_scores.nsmallest(10, 'RT_Norm'),shade=True)
kdes.legend_._set_loc(1)
plt.rcParams.update({'font.size': 6})
plt.title('Raitings for RT Critics 10 Worst Reviewed Films')
plt.xlim(0,5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ---
# ----
#
# <img src="https://upload.wikimedia.org/wikipedia/en/6/6f/Taken_3_poster.jpg">
#
# **Выводы: вот это да! Fandango показывал 3-4 звезды для фильмов, которые явно были неудачными!**
#
# **Больше всего отличается фильм [Taken 3!](https://www.youtube.com/watch?v=tJrfImRCHJ0) - Fandango дал ему рейтинг 4.5 звёзд, хотя этот фильм получил [средний рейтинг 1.86](https://en.wikipedia.org/wiki/Taken_3#Critical_response) от других компаний!**

# %%
norm_films.iloc[25]
# Out:
# STARS                     4.5
# RATING                    4.1
# RT_Norm                   0.4
# RTU_Norm                  2.3
# Meta_Norm                 1.3
# Meta_U_Norm               2.3
# IMDB_Norm                   3
# FILM           Taken 3 (2015)
# Name: 25, dtype: object

# %%
norm_scores['FILM']=all_sites['FILM']
norm_scores
# Out:
#      STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm  \
# 0      4.0     3.9      1.1       2.3        2.3          1.8        3.7
# 1      4.5     4.5      3.0       4.4        2.9          3.9        6.3
# 2      5.0     4.8      3.0       4.6        3.6          3.7        6.4
# 3      5.0     4.8      3.4       4.5        3.3          3.8        6.4
# 4      4.5     4.5      4.1       4.9        4.6          4.9        7.5
# ..     ...     ...      ...       ...        ...          ...        ...
# 140    3.5     3.5      3.7       3.4        3.4          3.6        5.8
# 141    4.0     3.6      4.0       4.4        4.3          3.5        6.1
# 142    4.5     4.2      3.9       4.5        3.3          3.9        6.8
# 143    4.0     3.9      4.0       4.6        4.2          4.1        6.4
# 144    3.5     3.1      2.5       2.5        3.3          3.2        5.5
#
#                                    FILM
# 0           Fifty Shades of Grey (2015)
# 1                 Jurassic World (2015)
# 2                American Sniper (2015)
# 3                      Furious 7 (2015)
# 4                     Inside Out (2015)
# ..                                  ...
# 140  Kumiko, The Treasure Hunter (2015)
# 141  The Diary of a Teenage Girl (2015)
# 142            The Wrecking Crew (2015)
# 143                    Tangerine (2015)
# 144            Maps to the Stars (2015)
#
# [145 rows x 8 columns]

# %%
norm_scores[norm_scores['FILM']=='Taken 3 (2015)']
# Out:
#     STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm  \
# 25    4.5     4.1      0.4       2.5        1.3          2.6        5.3
#
#               FILM
# 25  Taken 3 (2015)

# %%
norm_scores[norm_scores['FILM']=='Taken 3 (2015)'][['RT_Norm','RTU_Norm','Meta_Norm','Meta_U_Norm','IMDB_Norm']].mean(axis=1)
# Out:
# 25    2.42
# dtype: float64

# %%
pd.set_option('display.max_rows', None)

# %%
norm_scores
# Out:
#      STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm  \
# 0      4.0     3.9      1.1       2.3        2.3          1.8        3.7
# 1      4.5     4.5      3.0       4.4        2.9          3.9        6.3
# 2      5.0     4.8      3.0       4.6        3.6          3.7        6.4
# 3      5.0     4.8      3.4       4.5        3.3          3.8        6.4
# 4      4.5     4.5      4.1       4.9        4.6          4.9        7.5
# 5      4.5     4.3      2.6       4.1        2.9          3.9        6.5
# 6      4.5     4.2      3.2       4.5        2.9          4.4        6.8
# 7      4.0     4.0      2.3       2.8        2.8          3.2        5.8
# 8      5.0     4.5      3.1       4.6        3.3          3.9        6.8
# 9      3.5     3.4      3.0       2.7        3.4          3.4        5.2
# 10     5.0     4.5      3.6       4.3        3.3          4.2        6.2
# 11     5.0     4.5      3.4       4.9        3.2          4.5        6.8
# 12     4.5     4.3      4.1       4.8        4.4          4.8        7.2
# 13     4.5     4.3      2.1       3.1        2.1          3.1        5.7
# 14     4.5     4.1      2.1       3.8        2.9          3.6        6.3
# 15     4.5     4.3      3.9       4.4        3.7          3.5        6.3
# 16     4.5     4.4      2.6       3.5        3.0          3.0        5.5
# 17     4.5     4.1      3.6       4.0        3.7          3.3        5.8
# 18     5.0     4.8      3.8       5.1        3.6          4.1        7.3
# 19     4.0     3.7      2.1       2.9        3.0          3.6        5.7
# 20     5.0     4.6      3.8       5.0        3.6          4.6        7.0
# 21     4.5     4.4      1.9       3.5        2.7          4.1        5.8
# 22     4.5     4.2      1.3       3.3        2.1          3.0        5.6
# 23     5.0     4.6      4.2       4.6        4.4          3.9        6.5
# 24     4.5     4.2      1.1       3.3        1.6          2.7        4.5
# 25     4.5     4.1      0.4       2.5        1.3          2.6        5.3
# 26     4.5     4.4      1.1       3.6        1.7          1.8        5.8
# 27     4.5     4.1      1.9       3.1        2.4          3.6        5.7
# 28     3.0     2.7      0.4       1.1        1.3          1.4        3.5
# 29     4.5     4.2      1.1       3.2        1.9          3.6        6.0
# 30     4.0     3.9      1.2       2.6        1.7          2.1        5.3
# 31     5.0     4.6      2.5       4.3        2.8          4.6        6.8
# 32     4.5     4.1      2.1       3.1        2.3          3.2        5.5
# 33     4.0     3.9      2.4       2.9        2.8          3.4        5.7
# 34     4.5     4.2      2.8       3.7        3.1          3.2        5.8
# 35     3.5     3.3      3.3       3.0        3.1          3.6        5.3
# 36     4.5     4.2      1.3       3.7        1.9          2.9        6.2
# 37     4.0     3.7      3.9       4.2        4.3          4.4        6.9
# 38     3.5     3.4      1.1       2.2        2.0          2.5        4.8
# 39     4.5     4.3      4.1       4.4        3.8          4.6        6.3
# 40     4.5     4.1      0.7       2.9        1.3          2.9        4.9
# 41     4.0     3.8      1.1       3.0        1.7          3.4        5.5
# 42     4.0     3.8      1.3       3.1        2.0          4.1        6.1
# 43     4.5     4.1      3.9       4.6        3.9          4.4        6.7
# 44     4.5     4.5      1.5       3.9        2.3          3.3        6.1
# 45     5.0     4.6      3.3       4.8        3.0          4.0        6.5
# 46     4.5     4.2      2.3       3.7        2.5          4.1        6.3
# 47     4.5     4.1      2.5       3.0        2.6          3.8        5.5
# 48     4.0     3.5      3.6       3.5        4.0          3.8        5.7
# 49     3.5     3.5      0.2       1.9        0.6          1.3        3.7
# 50     4.0     3.6      0.4       1.9        1.5          3.1        4.0
# 51     3.0     2.8      1.3       1.3        2.3          2.1        4.3
# 52     4.5     4.1      2.9       4.3        2.7          4.4        6.6
# 53     4.0     3.7      3.9       4.3        3.8          4.6        6.6
# 54     4.0     3.7      0.3       2.0        1.5          2.1        4.3
# 55     4.5     4.5      1.3       3.9        1.6          2.7        6.3
# 56     3.0     2.7      2.5       2.1        2.9          3.2        5.1
# 57     4.5     4.4      2.2       4.4        2.5          4.0        6.4
# 58     3.5     3.1      0.8       1.7        2.0          2.2        4.8
# 59     4.5     4.2      3.0       3.7        2.8          3.6        5.7
# 60     4.5     4.3      3.7       4.6        3.6          4.0        6.5
# 61     3.0     2.9      4.0       3.5        4.1          4.2        6.0
# 62     4.5     4.1      2.5       3.2        2.9          4.1        5.7
# 63     3.0     2.9      0.7       1.5        1.5          3.9        3.8
# 64     4.0     3.9      2.6       3.4        2.5          3.4        5.7
# 65     4.5     4.2      1.6       3.7        2.2          4.4        5.7
# 66     4.0     3.7      1.4       2.5        2.3          3.0        5.6
# 67     5.0     4.5      0.8       4.5        1.1          2.6        4.7
# 68     4.0     3.8      2.3       3.1        2.8          3.4        6.0
# 69     3.0     3.0      0.6       1.2        1.5          2.7        4.5
# 70     4.0     3.8      3.0       3.7        3.1          4.2        6.1
# 71     4.0     3.7      2.7       2.9        2.7          3.9        5.4
# 72     3.0     2.8      1.4       1.4        2.5          3.0        4.7
# 73     4.0     3.8      0.8       2.8        1.7          4.7        5.7
# 74     4.0     4.0      3.7       4.2        3.3          4.4        6.4
# 75     3.0     3.0      0.9       1.4        2.1          2.4        4.3
# 76     4.5     4.1      3.7       4.6        3.6          4.3        6.5
# 77     3.5     3.2      0.5       1.9        1.5          2.2        4.8
# 78     3.5     3.2      0.5       1.6        1.3          1.8        4.8
# 79     3.5     3.4      0.7       2.7        1.2          2.9        5.0
# 80     3.0     2.9      3.1       2.8        4.0          4.1        5.8
# 81     3.5     3.0      0.6       1.5        1.4          1.9        4.4
# 82     3.5     3.4      0.7       1.8        1.9          2.4        5.0
# 83     3.5     3.3      0.5       1.8        1.5          2.8        4.8
# 84     4.0     3.9      0.3       2.6        1.4          1.8        5.1
# 85     4.5     4.0      4.2       4.4        4.0          4.9        6.4
# 86     4.5     4.0      3.7       4.7        4.0          4.7        6.8
# 87     3.5     3.2      0.5       1.5        1.6          2.1        4.7
# 88     4.0     3.6      0.5       2.2        1.2          1.3        5.5
# 89     4.5     4.3      0.8       4.4        1.5          3.3        6.4
# 90     4.5     4.0      3.5       4.2        3.5          4.2        6.3
# 91     4.5     4.4      4.1       4.9        4.2          4.9        7.0
# 92     4.5     4.2      4.0       4.2        3.6          4.2        6.3
# 93     3.5     3.4      3.8       3.7        3.9          3.9        6.2
# 94     4.0     3.7      1.9       2.8        2.5          3.8        5.7
# 95     4.5     4.3      3.4       4.8        3.7          4.7        7.1
# 96     3.5     3.2      1.9       2.2        2.5          3.2        5.5
# 97     4.0     4.0      3.2       4.1        2.9          3.9        6.2
# 98     3.5     3.4      2.1       2.5        2.4          3.6        5.7
# 99     4.5     4.5      2.2       4.5        2.5          3.9        6.3
# 100    3.0     2.9      3.5       2.8        3.8          3.7        5.6
# 101    4.5     4.0      2.7       3.4        2.5          3.8        6.3
# 102    4.0     3.7      1.1       2.4        2.0          2.9        5.6
# 103    3.5     3.2      4.1       3.0        4.6          3.7        6.0
# 104    4.0     3.6      4.0       3.8        3.7          3.8        6.0
# 105    4.5     4.3      4.0       4.6        3.7          4.6        6.6
# 106    4.0     3.5      1.8       2.9        2.6          4.2        6.0
# 107    4.5     4.1      4.0       5.0        3.8          4.9        7.1
# 108    4.0     3.5      3.5       3.2        3.1          3.7        5.6
# 109    3.0     2.9      0.5       1.1        1.8          3.0        4.0
# 110    3.5     3.5      4.1       4.4        4.1          4.2        6.3
# 111    3.5     3.4      3.7       3.6        3.9          3.9        5.9
# 112    4.0     3.9      3.4       4.3        3.8          4.4        6.3
# 113    4.0     3.9      3.4       4.1        3.2          4.4        6.3
# 114    4.5     4.1      3.9       4.8        4.1          4.2        6.9
# 115    3.5     3.5      4.1       4.2        4.4          4.9        6.4
# 116    3.5     3.3      3.5       3.5        3.2          4.8        6.0
# 117    4.5     4.4      2.5       3.2        3.0          3.8        5.2
# 118    3.5     3.3      2.3       1.7        2.6          3.6        4.9
# 119    4.5     4.3      4.0       4.9        4.1          4.3        7.3
# 120    4.0     3.9      1.7       2.5        2.5          3.9        5.6
# 121    4.0     3.6      2.2       2.5        2.7          3.8        5.3
# 122    4.0     3.6      4.2       4.2        4.5          3.8        6.3
# 123    3.5     3.4      4.2       4.4        4.5          4.4        6.3
# 124    4.5     4.3      4.2       5.0        4.2          4.6        7.1
# 125    3.5     3.4      3.5       3.9        3.7          3.9        6.2
# 126    4.0     3.5      4.2       4.3        4.5          4.0        6.7
# 127    4.0     3.9      2.8       3.7        2.9          2.6        6.2
# 128    3.5     3.5      4.2       4.4        4.4          4.1        6.8
# 129    4.0     3.6      3.0       2.5        3.3          3.8        5.1
# 130    4.0     3.7      1.1       1.8        1.9          4.4        5.5
# 131    4.5     4.1      4.0       4.6        4.0          4.1        6.7
# 132    4.0     3.9      3.5       4.7        3.4          4.7        6.2
# 133    3.0     3.0      0.8       1.4        1.8          2.9        4.7
# 134    4.0     3.9      2.2       2.8        2.8          3.8        5.7
# 135    4.5     4.1      3.7       4.8        3.5          3.6        6.8
# 136    3.5     3.1      2.1       2.4        2.6          3.8        5.5
# 137    4.0     3.6      4.1       4.6        4.3          5.3        7.1
# 138    4.5     4.1      3.9       3.9        3.8          4.3        6.5
# 139    4.5     4.2      4.2       4.7        4.1          3.3        6.7
# 140    3.5     3.5      3.7       3.4        3.4          3.6        5.8
# 141    4.0     3.6      4.0       4.4        4.3          3.5        6.1
# 142    4.5     4.2      3.9       4.5        3.3          3.9        6.8
# 143    4.0     3.9      4.0       4.6        4.2          4.1        6.4
# 144    3.5     3.1      2.5       2.5        3.3          3.2        5.5
#
#                                                   FILM
# 0                          Fifty Shades of Grey (2015)
# 1                                Jurassic World (2015)
# 2                               American Sniper (2015)
# 3                                     Furious 7 (2015)
# 4                                    Inside Out (2015)
# 5     The Hobbit: The Battle of the Five Armies (2014)
# 6                  Kingsman: The Secret Service (2015)
# 7                                       Minions (2015)
# 8                       Avengers: Age of Ultron (2015)
# 9                                Into the Woods (2014)
# 10                                   Cinderella (2015)
# 11                                      Ant-Man (2015)
# 12                           Mad Max: Fury Road (2015)
# 13                                  San Andreas (2015)
# 14                                     Unbroken (2014)
# 15                                          Spy (2015)
# 16                               Magic Mike XXL (2015)
# 17                                   Trainwreck (2015)
# 18                       Straight Outta Compton (2015)
# 19                                 Tomorrowland (2015)
# 20                           The Imitation Game (2014)
# 21                                         Home (2015)
# 22              The Divergent Series: Insurgent (2015)
# 23                                        Selma (2014)
# 24                                        Annie (2014)
# 25                                      Taken 3 (2015)
# 26                           The Wedding Ringer (2015)
# 27                                        Ted 2 (2015)
# 28                               Fantastic Four (2015)
# 29                           Terminator Genisys (2015)
# 30                                     Get Hard (2015)
# 31                                     Southpaw (2015)
# 32      Night at the Museum: Secret of the Tomb (2014)
# 33                                        Focus (2015)
# 34                              Pitch Perfect 2 (2015)
# 35     The SpongeBob Movie: Sponge Out of Water (2015)
# 36                                    Entourage (2015)
# 37                                      Birdman (2014)
# 38                            Jupiter Ascending (2015)
# 39                                   Paddington (2015)
# 40                                       Pixels (2015)
# 41                                     Vacation (2015)
# 42                                      Chappie (2015)
# 43                                   Ex Machina (2015)
# 44                                          Max (2015)
# 45                               McFarland, USA (2015)
# 46                           The Age of Adaline (2015)
# 47                         Insidious: Chapter 3 (2015)
# 48                                     Top Five (2014)
# 49                       Paul Blart: Mall Cop 2 (2015)
# 50                            The Boy Next Door (2015)
# 51                                  Poltergeist (2015)
# 52                      The Man From U.N.C.L.E. (2015)
# 53                                     The Gift (2015)
# 54                                  Hot Pursuit (2015)
# 55                             The Longest Ride (2015)
# 56                                   Unfriended (2015)
# 57                                Woman in Gold (2015)
# 58                                        Aloha (2015)
# 59                                     The DUFF (2015)
# 60                                         Dope (2015)
# 61                                   It Follows (2015)
# 62                                Run All Night (2015)
# 63                                  The Gallows (2015)
# 64        The Second Best Exotic Marigold Hotel (2015)
# 65                               Black or White (2015)
# 66                              Project Almanac (2015)
# 67                              Do You Believe? (2015)
# 68                                  Paper Towns (2015)
# 69                           The Lazarus Effect (2015)
# 70                                     Big Eyes (2014)
# 71                          Ricki and the Flash (2015)
# 72                                     Blackhat (2015)
# 73                                    Self/less (2015)
# 74                                   Mr. Holmes (2015)
# 75          The Woman In Black 2 Angel of Death (2015)
# 76                                  Still Alice (2015)
# 77                                  Seventh Son (2015)
# 78                                    Mortdecai (2015)
# 79                                Strange Magic (2015)
# 80                                Inherent Vice (2014)
# 81                       Hot Tub Time Machine 2 (2015)
# 82                                   The Gunman (2015)
# 83                                   Sinister 2 (2015)
# 84                             Hitman: Agent 47 (2015)
# 85                        Shaun the Sheep Movie (2015)
# 86                                 Love & Mercy (2015)
# 87                          Unfinished Business (2015)
# 88                                     The Loft (2015)
# 89                                   Little Boy (2015)
# 90                   Far From The Madding Crowd (2015)
# 91                                          Amy (2015)
# 92                               Monkey Kingdom (2015)
# 93                          A Most Violent Year (2014)
# 94                               American Ultra (2015)
# 95               Me and Earl and The Dying Girl (2015)
# 96                                   True Story (2015)
# 97                                Danny Collins (2015)
# 98                                         Cake (2015)
# 99                                  Spare Parts (2015)
# 100                           While We're Young (2015)
# 101                           The Water Diviner (2015)
# 102                                    Child 44 (2015)
# 103                                  Mr. Turner (2014)
# 104                   I'll See You In My Dreams (2015)
# 105                   What We Do in the Shadows (2015)
# 106                              Irrational Man (2015)
# 107                                  Wild Tales (2014)
# 108                                   Black Sea (2015)
# 109                           The Vatican Tapes (2015)
# 110                                         '71 (2015)
# 111                        Clouds of Sils Maria (2015)
# 112                          Testament of Youth (2015)
# 113                       Infinitely Polar Bear (2015)
# 114                         The End of the Tour (2015)
# 115                         Two Days, One Night (2014)
# 116                               The Overnight (2015)
# 117                         The Last Five Years (2015)
# 118                                      Maggie (2015)
# 119                       The Salt of the Earth (2015)
# 120                              A Little Chaos (2015)
# 121                                5 Flights Up (2015)
# 122                                    Timbuktu (2015)
# 123                                     Phoenix (2015)
# 124                             Song of the Sea (2014)
# 125                                The Wolfpack (2015)
# 126                                   Leviathan (2014)
# 127  The 100-Year-Old Man Who Climbed Out the Windo...
# 128          Gett: The Trial of Viviane Amsalem (2015)
# 129                               Welcome to Me (2015)
# 130                                 Dark Places (2015)
# 131                                    Red Army (2015)
# 132              The Stanford Prison Experiment (2015)
# 133                                      Serena (2015)
# 134                      Escobar: Paradise Lost (2015)
# 135                       When Marnie Was There (2015)
# 136                               Saint Laurent (2015)
# 137                                  About Elly (2015)
# 138                          The Hunting Ground (2015)
# 139                    Seymour: An Introduction (2015)
# 140                 Kumiko, The Treasure Hunter (2015)
# 141                 The Diary of a Teenage Girl (2015)
# 142                           The Wrecking Crew (2015)
# 143                                   Tangerine (2015)
# 144                           Maps to the Stars (2015)

# %%
pd.reset_option('display.max_rows')

# %%
norm_scores
# Out:
#      STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm  \
# 0      4.0     3.9      1.1       2.3        2.3          1.8        3.7
# 1      4.5     4.5      3.0       4.4        2.9          3.9        6.3
# 2      5.0     4.8      3.0       4.6        3.6          3.7        6.4
# 3      5.0     4.8      3.4       4.5        3.3          3.8        6.4
# 4      4.5     4.5      4.1       4.9        4.6          4.9        7.5
# ..     ...     ...      ...       ...        ...          ...        ...
# 140    3.5     3.5      3.7       3.4        3.4          3.6        5.8
# 141    4.0     3.6      4.0       4.4        4.3          3.5        6.1
# 142    4.5     4.2      3.9       4.5        3.3          3.9        6.8
# 143    4.0     3.9      4.0       4.6        4.2          4.1        6.4
# 144    3.5     3.1      2.5       2.5        3.3          3.2        5.5
#
#                                    FILM
# 0           Fifty Shades of Grey (2015)
# 1                 Jurassic World (2015)
# 2                American Sniper (2015)
# 3                      Furious 7 (2015)
# 4                     Inside Out (2015)
# ..                                  ...
# 140  Kumiko, The Treasure Hunter (2015)
# 141  The Diary of a Teenage Girl (2015)
# 142            The Wrecking Crew (2015)
# 143                    Tangerine (2015)
# 144            Maps to the Stars (2015)
#
# [145 rows x 8 columns]

# %% [markdown]
# ----
